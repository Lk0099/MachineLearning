# %% [markdown]
# <a href="https://colab.research.google.com/github/Lk0099/MachineLearning/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
rng = np.random.RandomState(42)
print(rng)
# Out:
# RandomState(MT19937)

# %%
x = 10 * rng.rand(50)
y = 2 * x - 1 + rng.randn(50)
plt.scatter(x, y) ;

# %%
plt.scatter([1,2,3,4,5],[10,20,30,40,50])

# %%
from sklearn.linear_model import LinearRegression

# %%
model= LinearRegression()




#LinearRegression(copy_X=True, fit_intercept=True,n_jobs=1, inter=False)

# %%
model
# Out:
# LinearRegression()

# %%
plt.scatter([1,2,3,4,5],[10,20,30,20,10])

# %%
model = LinearRegression()
#LinearRegression( copy_X=True, fit_intercept=True,n_jobs=1)
model
# Out:
# LinearRegression()

# %%
x = 10 * rng.rand(50) 
y = 2 * x - 1 + rng.randn(50)
X = x[:, np.newaxis]
X.shape
Y = y[:,np.newaxis]
Y.shape
print(X.shape)
print(Y.shape)
# Out:
# (50, 1)
# (50, 1)

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
LinearRegression( copy_X=True, fit_intercept=True, n_jobs=1)
# Out:
# LinearRegression(n_jobs=1)

# %%
model.coef_
# Out:
# array([[1.98468713]])

# %%
model.intercept_
# Out:
# array([-0.88699436])

# %%
plt.scatter(X,Y)

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import seaborn as sb
car = pd.read_csv("/content/cars.csv")
car.shape
car.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# ...

# %%
car.describe()
# Out:
#        Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# count        5076.000000        5076.000000       5076.000000
# mean          145.632191         127.825847        144.012411
# std            62.125026          77.358295         79.925899
# min             1.000000           2.000000          1.000000
# 25%           104.000000          60.000000         62.000000
# 50%           152.000000         128.000000        158.000000
# 75%           193.000000         198.000000        219.000000
# max           255.000000         255.000000        254.000000
#
#        Engine Information.Number of Forward Gears  Fuel Information.City mpg  \
# count                                 5076.000000                5076.000000
# mean                                     5.519110                  17.275808
# std                                      0.845637                   4.479485
# min                                      4.000000                   8.000000
# ...

# %%
car.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5076 entries, 0 to 5075
# Data columns (total 18 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Dimensions.Height                                5076 non-null   int64
#  1   Dimensions.Length                                5076 non-null   int64
#  2   Dimensions.Width                                 5076 non-null   int64
#  3   Engine Information.Driveline                     5076 non-null   object
#  4   Engine Information.Engine Type                   5076 non-null   object
#  5   Engine Information.Hybrid                        5076 non-null   bool
#  6   Engine Information.Number of Forward Gears       5076 non-null   int64
#  7   Engine Information.Transmission                  5076 non-null   object
#  8   Fuel Information.City mpg                        5076 non-null   int64
# ...

# %%
car.loc[car.duplicated()]
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 4                   140                143               202
# 121                  35                150                52
# 1389                212                108               135
# 2203                112                 22               181
# 2343                148                 98                57
# 3569                133                176               237
# 3570                143                176               237
# 3640                112                140               181
# 3703                145                202               224
# 3704                125                 36               166
# 3705                148                 51               226
# 4197                 95                253               212
# 4208                143                253               212
# 4313                138                 36               212
# ...

# %%
car.columns
# Out:
# Index(['Dimensions.Height', 'Dimensions.Length', 'Dimensions.Width',
#        'Engine Information.Driveline', 'Engine Information.Engine Type',
#        'Engine Information.Hybrid',
#        'Engine Information.Number of Forward Gears',
#        'Engine Information.Transmission', 'Fuel Information.City mpg',
#        'Fuel Information.Fuel Type', 'Fuel Information.Highway mpg',
#        'Identification.Classification', 'Identification.ID',
#        'Identification.Make', 'Identification.Model Year',
#        'Identification.Year',
#        'Engine Information.Engine Statistics.Horsepower',
#        'Engine Information.Engine Statistics.Torque'],
#       dtype='object')

# %%
car.head()
plt.figure(figsize=(10,10))
plt.style.use("seaborn")
car= car.corr()
sb.heatmap(car,cmap="copper",annot=True)
# Out:
# <ipython-input-24-fb49c19a0573>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")
# <ipython-input-24-fb49c19a0573>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car= car.corr()
# <Axes: >

# %%
print(type(car))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
car.describe()
# Out:
#        Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# count           9.000000           9.000000          9.000000
# mean            0.120390           0.111764          0.051048
# std             0.371551           0.334401          0.375546
# min            -0.220888          -0.041748         -0.220888
# 25%            -0.152407          -0.018854         -0.168376
# 50%             0.051030           0.016231         -0.023347
# 75%             0.245169           0.024901          0.036356
# max             1.000000           1.000000          1.000000
#
#        Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# count                        0.0                                    9.000000
# mean                         NaN                                    0.172615
# std                          NaN                                    0.343440
# min                          NaN                                   -0.168376
# ...

# %%
car.head()
# Out:
#                                             Dimensions.Height  \
# Dimensions.Height                                    1.000000
# Dimensions.Length                                    0.051030
# Dimensions.Width                                    -0.220888
# Engine Information.Hybrid                                 NaN
# Engine Information.Number of Forward Gears           0.057769
#
#                                             Dimensions.Length  \
# Dimensions.Height                                    0.051030
# Dimensions.Length                                    1.000000
# Dimensions.Width                                     0.016231
# Engine Information.Hybrid                                 NaN
# Engine Information.Number of Forward Gears          -0.041748
#
#                                             Dimensions.Width  \
# Dimensions.Height                                  -0.220888
# Dimensions.Length                                   0.016231
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Dimensions.Height to Engine Information.Engine Statistics.Torque
# Data columns (total 10 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Dimensions.Height                                9 non-null      float64
#  1   Dimensions.Length                                9 non-null      float64
#  2   Dimensions.Width                                 9 non-null      float64
#  3   Engine Information.Hybrid                        0 non-null      float64
#  4   Engine Information.Number of Forward Gears       9 non-null      float64
#  5   Fuel Information.City mpg                        9 non-null      float64
#  6   Fuel Information.Highway mpg                     9 non-null      float64
#  7   Identification.Year                              9 non-null      float64
# ...

# %%
car.isnull()# is checking the null values in  cars data in Boolean Values (True or False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# that is shows the how many null values in cars.csv (data) 
car.isnull().sum()
# Out:
# Dimensions.Height                                   1
# Dimensions.Length                                   1
# Dimensions.Width                                    1
# Engine Information.Hybrid                          10
# Engine Information.Number of Forward Gears          1
# Fuel Information.City mpg                           1
# Fuel Information.Highway mpg                        1
# Identification.Year                                 1
# Engine Information.Engine Statistics.Horsepower     1
# Engine Information.Engine Statistics.Torque         1
# dtype: int64

# %%
print(car)
# Out:
#                                                  Dimensions.Height  \
# Dimensions.Height                                         1.000000
# Dimensions.Length                                         0.051030
# Dimensions.Width                                         -0.220888
# Engine Information.Hybrid                                      NaN
# Engine Information.Number of Forward Gears                0.057769
# Fuel Information.City mpg                                 0.249385
# Fuel Information.Highway mpg                              0.245169
# Identification.Year                                       0.035920
# Engine Information.Engine Statistics.Horsepower          -0.152407
# Engine Information.Engine Statistics.Torque              -0.182470
#
#                                                  Dimensions.Length  \
# Dimensions.Height                                         0.051030
# Dimensions.Length                                         1.000000
# ...

# %%
car.head()
car= pd.DataFrame()
print(car)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import seaborn as sb
import matplotlib.pyplot as plt

cars = pd.read_csv("cars.csv")
cars.head()
plt.figure(figsize=(10,10))
plt.style.use("seaborn")
cars= cars.corr()
sb.heatmap(cars,cmap="spring", annot=True)
# Out:
# <ipython-input-33-4807403a4049>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")
# <ipython-input-33-4807403a4049>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cars= cars.corr()
# <Axes: >

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/cars.csv")
df.corr()
# Out:
# <ipython-input-41-95cb765a0820>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                                  Dimensions.Height  \
# Dimensions.Height                                         1.000000
# Dimensions.Length                                         0.051030
# Dimensions.Width                                         -0.220888
# Engine Information.Hybrid                                      NaN
# Engine Information.Number of Forward Gears                0.057769
# Fuel Information.City mpg                                 0.249385
# Fuel Information.Highway mpg                              0.245169
# Identification.Year                                       0.035920
# Engine Information.Engine Statistics.Horsepower          -0.152407
# ...
